# %% [markdown]
# **You need to adapt paths based on your current working directory to run the code**

# %%
#import packages
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import torchvision.models as models
import numpy as np
from copy import deepcopy
from glob import glob
import os
from os.path import basename

import matplotlib.pyplot as plt
from random import randint

import time

# mount drive
from google.colab import files, drive
drive.mount('/content/gdrive')
os.chdir('gdrive/MyDrive/results/')

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("device is ", device)
# Out:
# Mounted at /content/gdrive
# device is  cuda:0

# %%
def positive_associate_features(corr):

  # it returns a 2d array whose colums show the associations.  It also return 
  # a permuted version of corr in which the associted featurs of the larger dim
  # are sorted
  d1, d2 = corr.shape
  mindim = np.min([d1, d2])

  flat_index = np.empty((3, d1 * d2))
  
  ind = 0
  for i in range(d1):
    for j in range(d2):      
      flat_index[:, ind] = (int(i), int(j), corr[i, j])
      ind += 1

  flat_index = flat_index[:, np.argsort(- flat_index[2, :])]

  asdim1 = np.array([-1] * mindim)
  asdim2 = np.array([-1] * mindim)
  associated = 0
  ind = 0
  while associated < mindim:
    i, j = flat_index[:2, ind]
    if (i not in asdim1) and (j not in asdim2):
      asdim1[associated] = i
      asdim2[associated] = j
      associated += 1
    ind += 1

  
  if d1 <= d2:
    sortind = np.argsort(asdim1)
  else:
    sortind = np.argsort(asdim2)

  associates = np.array([asdim1[sortind], asdim2[sortind]])


  if d1 <= d2:
    rest = np.setdiff1d(flat_index[1, :], associates[1])
    permute = np.append(associates[1], rest)    

    # print('permute d2 is ', permute)
    permute_corr = corr[:, permute]
  else:
    rest = np.setdiff1d(flat_index[0, :], associates[0])
    permute = np.append(associates[0], rest)

    # print('permute d1 is ', permute)
    permute_corr = corr[permute, :]


  return associates, permute_corr

# %%
root = 'gdrive/MyDrive/Project/'

adds = glob(root + "*corr*")
adds = [add for add in adds if 'permute' not in add]
# print(*adds, sep='\n')

num = np.random.randint(0, len(adds) - 1)
print('num is', num , os.path.basename(adds[num]))
corr = torch.load(adds[num]).to(device)

asso1, _ = associate_features(corr)
asso2, _ = positive_associate_features(corr)

plt.subplots(figsize=(24,10))
plt.subplot(121)
ms = 2
plt.plot(asso1[0], asso1[1], '.', markersize=ms)
plt.plot(asso2[0], asso2[1], '.', markersize=ms)
plt.legend(['new', 'old'])

plt.subplot(122)
plt.plot(asso1[1], asso2[1], '.', markersize=ms)

# %%
# helper functions

def associate_features(corr):

  # it returns a 2d array whose colums show the associations.  It also return 
  # a permuted version of corr in which the associted featurs of the larger dim
  # are sorted
  d1, d2 = corr.shape
  mindim = np.min([d1, d2])

  flat_index = np.empty((3, d1 * d2))
  
  ind = 0
  for i in range(d1):
    for j in range(d2):      
      flat_index[:, ind] = (int(i), int(j), abs(corr[i, j]))
      ind += 1

  flat_index = flat_index[:, np.argsort(- flat_index[2, :])]

  asdim1 = np.array([-1] * mindim)
  asdim2 = np.array([-1] * mindim)
  associated = 0
  ind = 0
  while associated < mindim:
    i, j = flat_index[:2, ind]
    if (i not in asdim1) and (j not in asdim2):
      asdim1[associated] = i
      asdim2[associated] = j
      associated += 1
    ind += 1

  
  if d1 <= d2:
    sortind = np.argsort(asdim1)
  else:
    sortind = np.argsort(asdim2)

  associates = np.array([asdim1[sortind], asdim2[sortind]])


  if d1 <= d2:
    rest = np.setdiff1d(flat_index[1, :], associates[1])
    permute = np.append(associates[1], rest)    

    # print('permute d2 is ', permute)
    permute_corr = corr[:, permute]
  else:
    rest = np.setdiff1d(flat_index[0, :], associates[0])
    permute = np.append(associates[0], rest)

    # print('permute d1 is ', permute)
    permute_corr = corr[permute, :]


  return associates, permute_corr


def take_correlation(covariance, data1, data2):

  # send inputs to device
  covariance = covariance.to(device)
  data1 = data1.to(device)
  data2 = data2.to(device)

  # get standard deviations
  std_data1 = torch.std(data1, dim=0).reshape(-1, 1)
  std_data2 = torch.std(data2, dim=0).reshape(1, -1)

  # print('shape 1 & 2 are', std_data1.shape, std_data2.shape)

  stdmatrix = torch.matmul(std_data1, std_data2)

  corr = torch.div(covariance, stdmatrix)

  return corr
  

def take_covariance(data1, data2):
  
  # send inputs to device
  data1 = data1.to(device)
  data2 = data2.to(device)
  
  datasize = data1.shape[0]
  matrix_shape = (data1.shape[1], data2.shape[1])
  
  meandata1 = torch.sum(data1, dim=0) / datasize
  meandata1 = meandata1.repeat(datasize, 1)
  data1 -= meandata1

  cov = torch.matmul(torch.transpose(data1, 0, 1), data2) / datasize 

  return cov


def dataname_from_address(add):
  filename = basename(add)
  name = filename.split('-on-')[1]
  name = name.split('-')[0]

  return name

def get_save_cavariance(featadd1, featadd2,  
  saveroot= 'Simran/cov_corr_associate/'):


  data1_name, data2_name = dataname_from_address(featadd1), dataname_from_address(featadd2)

  if data1_name != data2_name:
    print('not matched data')
    return None
  else:
    saveroot += data1_name.replace('_trn', '') + "/"

  saveprefix = basename(featadd1) + "-vs-" + basename(featadd2)
  saveprefix = saveprefix.replace('_features.pt','')
  saveprefix = saveroot + saveprefix
  
  checkadd = saveprefix + '-permutedcorr.pt'
  if os.path.exists(checkadd):
    print('already exists')
    return None
  
  data1 = torch.load(featadd1)
  data2 = torch.load(featadd2)

  cov = take_covariance(data1=data1, data2=data2)
  corr =take_correlation(covariance=cov, data1=data1, data2=data2)
  asso, permute_corr = associate_features(corr=corr)

  covadd = saveprefix + '-cov.pt'
  torch.save(cov, covadd)
  # print('cov saved at:',covadd)

  corradd = saveprefix + '-corr.pt'
  torch.save(corr, corradd)

  assoadd = saveprefix + '-asso.pt'
  torch.save(asso, assoadd)

  permute_corradd = saveprefix + '-permutedcorr.pt'
  torch.save(permute_corr, permute_corradd)


'done'
# Out:
# 'done'

# %%
# save corr data
featroot = 'Saravanan/Vggnet_features/'
saveroot = 'Simran/cov_corr_associate/'
oldfeatroot = 'Saravanan/Features/'

featadds = glob(featroot + "*features*")
oldfeatadds = glob(oldfeatroot + "*features*")

# print(len(featadds), len(oldfeatadds))
# print(*featadds, sep='\n')
ind = 1
for add1 in featadds:
  # if ind > 5:
  #   break

  for add2 in featadds:
    # if ind > 5:
    #   break

    if add2 < add1:
      continue
    else:
      data1_name = dataname_from_address(add1)
      data2_name = dataname_from_address(add2)

      if data1_name == data2_name:
        get_save_cavariance(add1, add2, saveroot=saveroot)
        print(ind, basename(add1), basename(add2))
        ind += 1

print('\n start cross correlations \n')

for add1 in featadds:

  # if ind > 10:
  #   break

  for add2 in oldfeatadds:
    
    # if ind > 10:
    #   break

    data1_name = dataname_from_address(add1)
    data2_name = dataname_from_address(add2)

    if data1_name == data2_name:
        get_save_cavariance(add1, add2, saveroot=saveroot)
        print(ind, basename(add1), basename(add2))
        ind += 1
# Out:
# already exists
# 1 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 2 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 3 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 4 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 5 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 6 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 7 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 8 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 9 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 10 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 11 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 12 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 13 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 14 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 15 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 16 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 17 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 18 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 19 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 20 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 21 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 22 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 23 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 24 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 25 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 26 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 27 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 28 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 29 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 30 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 31 vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 32 vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 33 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 34 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 35 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 36 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 37 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 38 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 39 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 40 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 41 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 42 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 43 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 44 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 45 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 46 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 47 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 48 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 49 vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 50 vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 51 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 52 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 53 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 54 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 55 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 56 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 57 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 58 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 59 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 60 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 61 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 62 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 63 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 64 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 65 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 66 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 67 vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 68 vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 69 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 70 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 71 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 72 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 73 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 74 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 75 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 76 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 77 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 78 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 79 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 80 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 81 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 82 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 83 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 84 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 85 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 86 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 87 vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 88 vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 89 vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 90 vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 91 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 92 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 93 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 94 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 95 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 96 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 97 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 98 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 99 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 100 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 101 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 102 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 103 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 104 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 105 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 106 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 107 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 108 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 109 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 110 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 111 vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 112 vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 113 vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 114 vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 115 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 116 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 117 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 118 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 119 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 120 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 121 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 122 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 123 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 124 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 125 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 126 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 127 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 128 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 129 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 130 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 131 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 132 vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 133 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 134 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 135 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 136 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 137 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 138 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 139 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 140 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 141 vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 142 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 143 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 144 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 145 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 146 vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 147 vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 148 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 149 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 150 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 151 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 152 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 153 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 154 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 155 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 156 vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 157 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 158 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 159 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 160 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 161 vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 162 vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 163 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 164 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 165 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 166 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 167 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 168 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 169 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 170 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 171 vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 172 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 173 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 174 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 175 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 176 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 177 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 178 vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 179 vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 180 vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 181 vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 182 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 183 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 184 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt
# 185 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 186 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam_features.pt
# 187 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 188 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 189 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-sgd_features.pt
# 190 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 191 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 192 vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-sgd_features.pt
# 193 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 194 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 195 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 196 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 197 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 198 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 199 vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 200 vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 201 vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 202 vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 203 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 204 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 205 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# 206 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 207 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# 208 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 209 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 210 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-sgd_features.pt
# 211 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 212 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 213 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt
# 214 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 215 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 216 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 217 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 218 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 219 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 220 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 221 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 222 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 223 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 224 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 225 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 226 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 227 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 228 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 229 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 230 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 231 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-sgd_features.pt
# 232 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 233 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
# 234 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt
#
#  start cross correlations
#
# already exists
# 235 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 236 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 237 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 238 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 239 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 240 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 241 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 242 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 243 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 244 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 245 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 246 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 247 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 248 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 249 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 250 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 251 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 252 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 253 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 254 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 255 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 256 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 257 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 258 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 259 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 260 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 261 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 262 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 263 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 264 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 265 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# 266 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# 267 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# 268 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 269 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 270 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 271 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 272 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 273 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 274 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 275 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 276 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 277 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 278 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 279 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 280 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 281 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 282 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 283 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 284 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 285 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 286 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 287 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 288 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 289 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 290 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 291 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 292 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 293 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 294 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 295 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# 296 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# 297 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# 298 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 299 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 300 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 301 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 302 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 303 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 304 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 305 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 306 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# 307 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 308 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 309 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# 310 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 311 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 312 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 313 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 314 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 315 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 316 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 317 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 318 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# 319 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 320 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 321 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# 322 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 323 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 324 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# 325 vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam_features.pt resnet18-init=pre_trained-on-mnist_trn-20epochs-SGD_features.pt
# ...
# 1217 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt resnet18-init=negative_pre_trained-on-fmnist_trn-20epochs-adam_features.pt
# already exists
# 1218 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt resnet18-init=distorted_pre_trained-on-fmnist_trn-20epochs-adam_features.pt
# already exists
# 1219 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt resnet18-init=kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# already exists
# 1220 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# already exists
# 1221 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam_features.pt
# already exists
# 1222 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt resnet18-init=kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# already exists
# 1223 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# already exists
# 1224 vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam_features.pt
# already exists
# 1225 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1226 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1227 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1228 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1229 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1230 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1231 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1232 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1233 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1234 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1235 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1236 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1237 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1238 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1239 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1240 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1241 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1242 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1243 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1244 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1245 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1246 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1247 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1248 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1249 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1250 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1251 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1252 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1253 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1254 vgg19-init=kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1255 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1256 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1257 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1258 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1259 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1260 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1261 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1262 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1263 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1264 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1265 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1266 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1267 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1268 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1269 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1270 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1271 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1272 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1273 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1274 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1275 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1276 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1277 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1278 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1279 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1280 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1281 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1282 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1283 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1284 vgg19-init=negative_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1285 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1286 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1287 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1288 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1289 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1290 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1291 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1292 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1293 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1294 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1295 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1296 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1297 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1298 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1299 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-SGD_features.pt
# already exists
# 1300 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1301 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1302 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1303 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1304 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1305 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt lenet-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1306 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1307 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1308 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_pre_trained-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1309 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1310 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1311 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1312 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1313 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=negative_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
# already exists
# 1314 vgg19-init=distorted_kaiming_normal-on-cifar_trn-20epochs-sgd_features.pt resnet18-init=distorted_kaiming_normal-on-cifar_trn-20epochs-adam_features.pt
