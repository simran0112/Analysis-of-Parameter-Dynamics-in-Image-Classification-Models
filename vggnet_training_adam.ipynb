# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import torchvision.models as models
import numpy as np
from copy import deepcopy

import matplotlib.pyplot as plt
from random import randint
from torchvision.datasets import MNIST

import time

import os
# !ls
from google.colab import drive
drive.mount('/content/drive')

os.chdir("/content/drive/MyDrive/Saravanan/")
from datasets import return_dataset
[[mnist_train, mnist_test], [fashionmnist_train, fashionmnist_test], [cifar10_train, cifar10_test]] = return_dataset()
datasets = [[mnist_train, mnist_test], [fashionmnist_train, fashionmnist_test], [cifar10_train, cifar10_test]]

from initializations import initialize, negative_model, distorted_model
# Out:
# sample_data
# Mounted at /content/drive
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# }#trainer function

import copy
from os import path, mkdir


def train_model(model, dataloaders, criterion, optimizer, num_epochs=25,
                folder = "/content/drive/MyDrive/Saravanan/training_data_vggnet/", save_epochs=[]):
    since = time.time()

    val_acc_history = []
    train_acc_history = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:               
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                  # Get model outputs and calculate loss
                  # Special case for inception because in training it has an auxiliary output. In train
                  #   mode we calculate the loss by summing the final output and the auxiliary output
                  #   but in testing we only consider the final output.
                  outputs = model(inputs)
                  loss = criterion(outputs, labels)

                  _, preds = torch.max(outputs, 1)

                  # backward + optimize only if in training phase
                  if phase == 'train':
                      loss.backward()
                      optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
            

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)
            elif phase == 'train':
                train_acc_history.append(epoch_acc)

        print()

        # saving requested epochs
        if epoch in save_epochs:        
          add = folder + "epoch_" + str(epoch) + '.pt'          
          torch.save(model, add)
          print("saved epoch", epoch, 'on', add[-60:])

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history, train_acc_history

# %%
def run_train(model, traindata, testdata, 
              lr=0.001, momemntum=0.9, epochsnum=20, batch_size=128, num_workers=2,
              rootadd = "/content/drive/MyDrive/Saravanan/training_data_vggnet/",
              save_epochs=[]):

  name = model.name + '-init=' + model.initname + "-on-" + traindata.name + '-' + str(epochsnum) + "epochs" + "-" + model.optimizer
  folderadd = rootadd + name
  
  
  # check folder does not exsit
  trynumber = 2
  testadd = folderadd
  while path.exists(testadd):
    testadd = folderadd + '_try' + str(trynumber)
    trynumber += 1
  folderadd = testadd + "/"
  mkdir(folderadd)

  initadd = folderadd + "initial_model.pt"
  torch.save(model, initadd)



  trainloader = torch.utils.data.DataLoader(traindata, batch_size=batch_size,
                                          shuffle=True, num_workers=num_workers)
  testloader = torch.utils.data.DataLoader(testdata, batch_size=batch_size,
                                         shuffle=False, num_workers=num_workers)
  dataloaders_dict = {'train': trainloader, 'val': testloader}
  
  criterion = torch.nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=0.005, eps=1e-1)

  model.to(device)
  print('\n' * 3)
  print(name + '\n' + '='*len(name))
  model, test_history, train_history = train_model(model=model, dataloaders=dataloaders_dict,
                    criterion=criterion, optimizer=optimizer, num_epochs=epochsnum,
                    folder=folderadd, save_epochs=save_epochs)

  model.traindata = traindata.name
  model.train_history = train_history
  model.test_history = test_history
  model.epochs_trained = epochsnum  

  # save model
  modeladd = folderadd[:-1] + ".pt"
  torch.save(model, modeladd)
  return model
'done'
# Out:
# 'done'

# %%
# train models
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

initlist = [ 'kaiming_uniform', 'kaiming_normal']
# datasets = [[mnist_train, mnist_test], [fashionmnist_train, fashionmnist_test], [cifar10_train, cifar10_test]]

epochsnum = 20
lr = 0.005
momemntum=0.9
batch_size=512
num_workers=2
save_epochs = [x for x in range(epochsnum) if x%5 == 0]

features_size = 512
classes_size = 10


for initname in initlist:
    if initname == 'pre_trained':
      model = models.vgg19(pretrained=True)
      model.name = 'vgg19'
      model.optimizer = 'adam'
      model.fc = torch.nn.Linear(features_size, classes_size, bias=True)
      model.initname = initname
    else:
      model = models.vgg19(pretrained=False)
      model.name = 'vgg19'
      model.optimizer = 'adam'
      model.fc = torch.nn.Linear(features_size, classes_size, bias=True)

      initialize(model, initname)

    for data in datasets:

      finalmodel = run_train(model=model, traindata=data[0], testdata=data[1],
                epochsnum=epochsnum, save_epochs=save_epochs)
      if initlist=='pretrained':
        pass
      else:
        negativemodel = negative_model(finalmodel)
        run_train(model=negativemodel, traindata=data[0], testdata=data[1],
                epochsnum=epochsnum, save_epochs=save_epochs)
      
      distortedmodel = distorted_model(finalmodel)
      run_train(model=distortedmodel, traindata=data[0], testdata=data[1],
                epochsnum=epochsnum, save_epochs=save_epochs)
# Out:
# vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam
# =====================================================
# Epoch 0/19
# ----------
# train Loss: 2.1112 Acc: 0.3403
# val Loss: 0.6442 Acc: 0.7512
#
# saved epoch 0 on 9-init=kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.1688 Acc: 0.9559
# val Loss: 0.0622 Acc: 0.9837
#
# Epoch 2/19
# ----------
# train Loss: 0.0602 Acc: 0.9848
# val Loss: 0.0733 Acc: 0.9801
#
# Epoch 3/19
# ----------
# train Loss: 0.0406 Acc: 0.9891
# val Loss: 0.0442 Acc: 0.9879
#
# Epoch 4/19
# ----------
# train Loss: 0.0318 Acc: 0.9913
# val Loss: 0.0318 Acc: 0.9907
#
# Epoch 5/19
# ----------
# train Loss: 0.0260 Acc: 0.9927
# val Loss: 0.0285 Acc: 0.9908
#
# saved epoch 5 on 9-init=kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.0184 Acc: 0.9949
# val Loss: 0.0315 Acc: 0.9908
#
# Epoch 7/19
# ----------
# train Loss: 0.0132 Acc: 0.9960
# val Loss: 0.0276 Acc: 0.9919
#
# Epoch 8/19
# ----------
# train Loss: 0.0134 Acc: 0.9961
# val Loss: 0.0285 Acc: 0.9927
#
# Epoch 9/19
# ----------
# train Loss: 0.0091 Acc: 0.9974
# val Loss: 0.0386 Acc: 0.9913
#
# Epoch 10/19
# ----------
# train Loss: 0.0087 Acc: 0.9977
# val Loss: 0.0343 Acc: 0.9917
#
# saved epoch 10 on -init=kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.0065 Acc: 0.9983
# val Loss: 0.0343 Acc: 0.9921
#
# Epoch 12/19
# ----------
# train Loss: 0.0061 Acc: 0.9983
# val Loss: 0.0298 Acc: 0.9934
#
# Epoch 13/19
# ----------
# train Loss: 0.0052 Acc: 0.9986
# val Loss: 0.0307 Acc: 0.9942
#
# Epoch 14/19
# ----------
# train Loss: 0.0038 Acc: 0.9991
# val Loss: 0.0334 Acc: 0.9914
#
# Epoch 15/19
# ----------
# train Loss: 0.0055 Acc: 0.9985
# val Loss: 0.0317 Acc: 0.9931
#
# saved epoch 15 on -init=kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0042 Acc: 0.9989
# val Loss: 0.0335 Acc: 0.9928
#
# Epoch 17/19
# ----------
# train Loss: 0.0031 Acc: 0.9992
# val Loss: 0.0353 Acc: 0.9929
#
# Epoch 18/19
# ----------
# train Loss: 0.0022 Acc: 0.9994
# val Loss: 0.0314 Acc: 0.9937
#
# Epoch 19/19
# ----------
# train Loss: 0.0021 Acc: 0.9994
# val Loss: 0.0347 Acc: 0.9934
#
# Training complete in 25m 37s
# Best val Acc: 0.994200
#
#
#
#
# vgg19-init=negative_kaiming_uniform-on-mnist_trn-20epochs-adam
# ==============================================================
# Epoch 0/19
# ----------
# train Loss: 121211459.1684 Acc: 0.1073
# val Loss: 2.3859 Acc: 0.1135
#
# saved epoch 0 on gative_kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 2.3585 Acc: 0.1032
# val Loss: 2.3263 Acc: 0.1135
#
# Epoch 2/19
# ----------
# train Loss: 2.3360 Acc: 0.1011
# val Loss: 2.3159 Acc: 0.1135
#
# Epoch 3/19
# ----------
# train Loss: 2.3287 Acc: 0.1051
# val Loss: 2.3116 Acc: 0.1135
#
# Epoch 4/19
# ----------
# train Loss: 2.3288 Acc: 0.1023
# val Loss: 2.3100 Acc: 0.1135
#
# Epoch 5/19
# ----------
# train Loss: 2.3267 Acc: 0.1024
# val Loss: 2.3084 Acc: 0.1135
#
# saved epoch 5 on gative_kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 2.3264 Acc: 0.1035
# val Loss: 2.3078 Acc: 0.1135
#
# Epoch 7/19
# ----------
# train Loss: 2.3258 Acc: 0.1007
# val Loss: 2.3069 Acc: 0.1135
#
# Epoch 8/19
# ----------
# train Loss: 2.3239 Acc: 0.1035
# val Loss: 2.3065 Acc: 0.1135
#
# Epoch 9/19
# ----------
# train Loss: 2.3222 Acc: 0.1055
# val Loss: 2.3060 Acc: 0.1135
#
# Epoch 10/19
# ----------
# train Loss: 2.3243 Acc: 0.1036
# val Loss: 2.3060 Acc: 0.1135
#
# saved epoch 10 on ative_kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 2.3227 Acc: 0.1018
# val Loss: 2.3059 Acc: 0.1135
#
# Epoch 12/19
# ----------
# train Loss: 2.3220 Acc: 0.1038
# val Loss: 2.3053 Acc: 0.1135
#
# Epoch 13/19
# ----------
# train Loss: 2.3243 Acc: 0.1001
# val Loss: 2.3054 Acc: 0.1135
#
# Epoch 14/19
# ----------
# train Loss: 2.3214 Acc: 0.1030
# val Loss: 2.3054 Acc: 0.1135
#
# Epoch 15/19
# ----------
# train Loss: 2.3218 Acc: 0.1029
# val Loss: 2.3052 Acc: 0.1135
#
# saved epoch 15 on ative_kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 2.3214 Acc: 0.1027
# val Loss: 2.3050 Acc: 0.1135
#
# Epoch 17/19
# ----------
# train Loss: 2.3203 Acc: 0.1040
# val Loss: 2.3053 Acc: 0.1135
#
# Epoch 18/19
# ----------
# train Loss: 2.3217 Acc: 0.1037
# val Loss: 2.3046 Acc: 0.1135
#
# Epoch 19/19
# ----------
# train Loss: 2.3219 Acc: 0.1008
# val Loss: 2.3046 Acc: 0.1135
#
# Training complete in 24m 47s
# Best val Acc: 0.113500
#
#
#
#
# vgg19-init=distorted_kaiming_uniform-on-mnist_trn-20epochs-adam
# ===============================================================
# Epoch 0/19
# ----------
# train Loss: 0.0054 Acc: 0.9984
# val Loss: 0.0299 Acc: 0.9932
#
# saved epoch 0 on torted_kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.0053 Acc: 0.9983
# val Loss: 0.0334 Acc: 0.9926
#
# Epoch 2/19
# ----------
# train Loss: 0.0035 Acc: 0.9989
# val Loss: 0.0312 Acc: 0.9940
#
# Epoch 3/19
# ----------
# train Loss: 0.0045 Acc: 0.9987
# val Loss: 0.0340 Acc: 0.9927
#
# Epoch 4/19
# ----------
# train Loss: 0.0045 Acc: 0.9988
# val Loss: 0.0383 Acc: 0.9925
#
# Epoch 5/19
# ----------
# train Loss: 0.0036 Acc: 0.9990
# val Loss: 0.0347 Acc: 0.9924
#
# saved epoch 5 on torted_kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.0018 Acc: 0.9994
# val Loss: 0.0372 Acc: 0.9927
#
# Epoch 7/19
# ----------
# train Loss: 0.0011 Acc: 0.9997
# val Loss: 0.0372 Acc: 0.9938
#
# Epoch 8/19
# ----------
# train Loss: 0.0041 Acc: 0.9989
# val Loss: 0.0293 Acc: 0.9930
#
# Epoch 9/19
# ----------
# train Loss: 0.0007 Acc: 0.9998
# val Loss: 0.0335 Acc: 0.9942
#
# Epoch 10/19
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0368 Acc: 0.9939
#
# saved epoch 10 on orted_kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0371 Acc: 0.9942
#
# Epoch 12/19
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0414 Acc: 0.9941
#
# Epoch 13/19
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0390 Acc: 0.9941
#
# Epoch 14/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0407 Acc: 0.9940
#
# Epoch 15/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0414 Acc: 0.9941
#
# saved epoch 15 on orted_kaiming_uniform-on-mnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0420 Acc: 0.9942
#
# Epoch 17/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0428 Acc: 0.9941
#
# Epoch 18/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0434 Acc: 0.9940
#
# Epoch 19/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0438 Acc: 0.9941
#
# Training complete in 25m 44s
# Best val Acc: 0.994200
#
#
#
#
# vgg19-init=kaiming_uniform-on-fmnist_trn-20epochs-adam
# ======================================================
# Epoch 0/19
# ----------
# train Loss: 0.7052 Acc: 0.7548
# val Loss: 0.4031 Acc: 0.8636
#
# saved epoch 0 on -init=kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.3549 Acc: 0.8743
# val Loss: 0.3582 Acc: 0.8736
#
# Epoch 2/19
# ----------
# train Loss: 0.2929 Acc: 0.8954
# val Loss: 0.2947 Acc: 0.8977
#
# Epoch 3/19
# ----------
# train Loss: 0.2509 Acc: 0.9106
# val Loss: 0.2963 Acc: 0.8975
#
# Epoch 4/19
# ----------
# train Loss: 0.2234 Acc: 0.9190
# val Loss: 0.2637 Acc: 0.9097
#
# Epoch 5/19
# ----------
# train Loss: 0.1947 Acc: 0.9294
# val Loss: 0.2463 Acc: 0.9127
#
# saved epoch 5 on -init=kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.1774 Acc: 0.9365
# val Loss: 0.2813 Acc: 0.9076
#
# Epoch 7/19
# ----------
# train Loss: 0.1620 Acc: 0.9420
# val Loss: 0.2706 Acc: 0.9119
#
# Epoch 8/19
# ----------
# train Loss: 0.1430 Acc: 0.9491
# val Loss: 0.2502 Acc: 0.9187
#
# Epoch 9/19
# ----------
# train Loss: 0.1262 Acc: 0.9544
# val Loss: 0.2890 Acc: 0.9143
#
# Epoch 10/19
# ----------
# train Loss: 0.1159 Acc: 0.9572
# val Loss: 0.2672 Acc: 0.9174
#
# saved epoch 10 on init=kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.1043 Acc: 0.9618
# val Loss: 0.2820 Acc: 0.9196
#
# Epoch 12/19
# ----------
# train Loss: 0.0904 Acc: 0.9672
# val Loss: 0.2905 Acc: 0.9173
#
# Epoch 13/19
# ----------
# train Loss: 0.0829 Acc: 0.9700
# val Loss: 0.2887 Acc: 0.9132
#
# Epoch 14/19
# ----------
# train Loss: 0.0739 Acc: 0.9732
# val Loss: 0.3039 Acc: 0.9181
#
# Epoch 15/19
# ----------
# train Loss: 0.0681 Acc: 0.9758
# val Loss: 0.2979 Acc: 0.9179
#
# saved epoch 15 on init=kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0601 Acc: 0.9786
# val Loss: 0.3319 Acc: 0.9120
#
# Epoch 17/19
# ----------
# train Loss: 0.0549 Acc: 0.9805
# val Loss: 0.3648 Acc: 0.9190
#
# Epoch 18/19
# ----------
# train Loss: 0.0531 Acc: 0.9809
# val Loss: 0.3139 Acc: 0.9202
#
# Epoch 19/19
# ----------
# train Loss: 0.0414 Acc: 0.9855
# val Loss: 0.3365 Acc: 0.9215
#
# Training complete in 25m 45s
# Best val Acc: 0.921500
#
#
#
#
# vgg19-init=negative_kaiming_uniform-on-fmnist_trn-20epochs-adam
# ===============================================================
# Epoch 0/19
# ----------
# train Loss: 255102513.4815 Acc: 0.1004
# val Loss: 2.3704 Acc: 0.1000
#
# saved epoch 0 on ative_kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 2.3561 Acc: 0.1013
# val Loss: 2.3274 Acc: 0.1000
#
# Epoch 2/19
# ----------
# train Loss: 2.3397 Acc: 0.0989
# val Loss: 2.3181 Acc: 0.1000
#
# Epoch 3/19
# ----------
# train Loss: 2.3330 Acc: 0.0986
# val Loss: 2.3141 Acc: 0.1000
#
# Epoch 4/19
# ----------
# train Loss: 2.3314 Acc: 0.1003
# val Loss: 2.3119 Acc: 0.1000
#
# Epoch 5/19
# ----------
# train Loss: 2.3297 Acc: 0.0999
# val Loss: 2.3105 Acc: 0.1000
#
# saved epoch 5 on ative_kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 2.3290 Acc: 0.0994
# val Loss: 2.3096 Acc: 0.1000
#
# Epoch 7/19
# ----------
# train Loss: 2.3290 Acc: 0.1012
# val Loss: 2.3090 Acc: 0.1000
#
# Epoch 8/19
# ----------
# train Loss: 2.3277 Acc: 0.0987
# val Loss: 2.3085 Acc: 0.1000
#
# Epoch 9/19
# ----------
# train Loss: 2.3277 Acc: 0.1002
# val Loss: 2.3081 Acc: 0.1000
#
# Epoch 10/19
# ----------
# train Loss: 2.3267 Acc: 0.1003
# val Loss: 2.3078 Acc: 0.1000
#
# saved epoch 10 on tive_kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 2.3267 Acc: 0.0997
# val Loss: 2.3076 Acc: 0.1000
#
# Epoch 12/19
# ----------
# train Loss: 2.3252 Acc: 0.1035
# val Loss: 2.3075 Acc: 0.1000
#
# Epoch 13/19
# ----------
# train Loss: 2.3268 Acc: 0.1000
# val Loss: 2.3072 Acc: 0.1000
#
# Epoch 14/19
# ----------
# train Loss: 2.3248 Acc: 0.1006
# val Loss: 2.3072 Acc: 0.1000
#
# Epoch 15/19
# ----------
# train Loss: 2.3261 Acc: 0.1000
# val Loss: 2.3070 Acc: 0.1000
#
# saved epoch 15 on tive_kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 2.3255 Acc: 0.1009
# val Loss: 2.3068 Acc: 0.1000
#
# Epoch 17/19
# ----------
# train Loss: 2.3251 Acc: 0.1017
# val Loss: 2.3068 Acc: 0.1000
#
# Epoch 18/19
# ----------
# train Loss: 2.3258 Acc: 0.0986
# val Loss: 2.3066 Acc: 0.1000
#
# Epoch 19/19
# ----------
# train Loss: 2.3267 Acc: 0.0996
# val Loss: 2.3066 Acc: 0.1000
#
# Training complete in 24m 48s
# Best val Acc: 0.100000
#
#
#
#
# vgg19-init=distorted_kaiming_uniform-on-fmnist_trn-20epochs-adam
# ================================================================
# Epoch 0/19
# ----------
# train Loss: 0.0406 Acc: 0.9852
# val Loss: 0.3629 Acc: 0.9186
#
# saved epoch 0 on orted_kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.0386 Acc: 0.9865
# val Loss: 0.3700 Acc: 0.9180
#
# Epoch 2/19
# ----------
# train Loss: 0.0378 Acc: 0.9871
# val Loss: 0.3375 Acc: 0.9195
#
# Epoch 3/19
# ----------
# train Loss: 0.0314 Acc: 0.9891
# val Loss: 0.3872 Acc: 0.9151
#
# Epoch 4/19
# ----------
# train Loss: 0.0301 Acc: 0.9896
# val Loss: 0.3533 Acc: 0.9204
#
# Epoch 5/19
# ----------
# train Loss: 0.0276 Acc: 0.9904
# val Loss: 0.4008 Acc: 0.9164
#
# saved epoch 5 on orted_kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.0213 Acc: 0.9931
# val Loss: 0.4094 Acc: 0.9187
#
# Epoch 7/19
# ----------
# train Loss: 0.0217 Acc: 0.9918
# val Loss: 0.4409 Acc: 0.9154
#
# Epoch 8/19
# ----------
# train Loss: 0.0221 Acc: 0.9926
# val Loss: 0.4360 Acc: 0.9161
#
# Epoch 9/19
# ----------
# train Loss: 0.0200 Acc: 0.9932
# val Loss: 0.4111 Acc: 0.9206
#
# Epoch 10/19
# ----------
# train Loss: 0.0199 Acc: 0.9931
# val Loss: 0.4192 Acc: 0.9224
#
# saved epoch 10 on rted_kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.0177 Acc: 0.9939
# val Loss: 0.4185 Acc: 0.9198
#
# Epoch 12/19
# ----------
# train Loss: 0.0186 Acc: 0.9936
# val Loss: 0.4022 Acc: 0.9242
#
# Epoch 13/19
# ----------
# train Loss: 0.0150 Acc: 0.9948
# val Loss: 0.4295 Acc: 0.9215
#
# Epoch 14/19
# ----------
# train Loss: 0.0127 Acc: 0.9958
# val Loss: 0.4452 Acc: 0.9219
#
# Epoch 15/19
# ----------
# train Loss: 0.0149 Acc: 0.9952
# val Loss: 0.4363 Acc: 0.9215
#
# saved epoch 15 on rted_kaiming_uniform-on-fmnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0117 Acc: 0.9960
# val Loss: 0.4668 Acc: 0.9205
#
# Epoch 17/19
# ----------
# train Loss: 0.0124 Acc: 0.9958
# val Loss: 0.4393 Acc: 0.9226
#
# Epoch 18/19
# ----------
# train Loss: 0.0110 Acc: 0.9962
# val Loss: 0.4497 Acc: 0.9241
#
# Epoch 19/19
# ----------
# train Loss: 0.0089 Acc: 0.9970
# val Loss: 0.4559 Acc: 0.9233
#
# Training complete in 25m 47s
# Best val Acc: 0.924200
#
#
#
#
# vgg19-init=kaiming_uniform-on-cifar_trn-20epochs-adam
# =====================================================
# Epoch 0/19
# ----------
# train Loss: 2.2349 Acc: 0.1496
# val Loss: 1.9116 Acc: 0.2158
#
# saved epoch 0 on 9-init=kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 1.7860 Acc: 0.2850
# val Loss: 1.5689 Acc: 0.3748
#
# Epoch 2/19
# ----------
# train Loss: 1.4702 Acc: 0.4353
# val Loss: 1.2634 Acc: 0.5382
#
# Epoch 3/19
# ----------
# train Loss: 1.1994 Acc: 0.5608
# val Loss: 1.1004 Acc: 0.6018
#
# Epoch 4/19
# ----------
# train Loss: 1.0236 Acc: 0.6300
# val Loss: 1.0303 Acc: 0.6312
#
# Epoch 5/19
# ----------
# train Loss: 0.8840 Acc: 0.6860
# val Loss: 0.9170 Acc: 0.6847
#
# saved epoch 5 on 9-init=kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.7834 Acc: 0.7248
# val Loss: 0.9341 Acc: 0.6850
#
# Epoch 7/19
# ----------
# train Loss: 0.6785 Acc: 0.7660
# val Loss: 0.9337 Acc: 0.6828
#
# Epoch 8/19
# ----------
# train Loss: 0.6055 Acc: 0.7921
# val Loss: 0.8551 Acc: 0.7209
#
# Epoch 9/19
# ----------
# train Loss: 0.5166 Acc: 0.8245
# val Loss: 0.8580 Acc: 0.7227
#
# Epoch 10/19
# ----------
# train Loss: 0.4542 Acc: 0.8445
# val Loss: 0.9003 Acc: 0.7180
#
# saved epoch 10 on -init=kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.3996 Acc: 0.8641
# val Loss: 0.9857 Acc: 0.7231
#
# Epoch 12/19
# ----------
# train Loss: 0.3444 Acc: 0.8828
# val Loss: 0.9928 Acc: 0.7253
#
# Epoch 13/19
# ----------
# train Loss: 0.2988 Acc: 0.8992
# val Loss: 0.9121 Acc: 0.7425
#
# Epoch 14/19
# ----------
# train Loss: 0.2657 Acc: 0.9103
# val Loss: 0.9457 Acc: 0.7351
#
# Epoch 15/19
# ----------
# train Loss: 0.2094 Acc: 0.9298
# val Loss: 1.0086 Acc: 0.7350
#
# saved epoch 15 on -init=kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.1978 Acc: 0.9332
# val Loss: 1.0509 Acc: 0.7369
#
# Epoch 17/19
# ----------
# train Loss: 0.1695 Acc: 0.9427
# val Loss: 1.0508 Acc: 0.7228
#
# Epoch 18/19
# ----------
# train Loss: 0.1510 Acc: 0.9490
# val Loss: 1.0773 Acc: 0.7419
#
# Epoch 19/19
# ----------
# train Loss: 0.1352 Acc: 0.9547
# val Loss: 1.2485 Acc: 0.7253
#
# Training complete in 21m 35s
# Best val Acc: 0.742500
#
#
#
#
# vgg19-init=negative_kaiming_uniform-on-cifar_trn-20epochs-adam
# ==============================================================
# Epoch 0/19
# ----------
# train Loss: 591775042.1085 Acc: 0.1000
# val Loss: 2.4255 Acc: 0.1000
#
# saved epoch 0 on gative_kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 2.3819 Acc: 0.0979
# val Loss: 2.3398 Acc: 0.1000
#
# Epoch 2/19
# ----------
# train Loss: 2.3479 Acc: 0.0969
# val Loss: 2.3243 Acc: 0.1000
#
# Epoch 3/19
# ----------
# train Loss: 2.3383 Acc: 0.0992
# val Loss: 2.3181 Acc: 0.1000
#
# Epoch 4/19
# ----------
# train Loss: 2.3334 Acc: 0.1006
# val Loss: 2.3148 Acc: 0.1000
#
# Epoch 5/19
# ----------
# train Loss: 2.3325 Acc: 0.0986
# val Loss: 2.3127 Acc: 0.1000
#
# saved epoch 5 on gative_kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 2.3321 Acc: 0.0988
# val Loss: 2.3116 Acc: 0.1000
#
# Epoch 7/19
# ----------
# train Loss: 2.3285 Acc: 0.1016
# val Loss: 2.3104 Acc: 0.1000
#
# Epoch 8/19
# ----------
# train Loss: 2.3293 Acc: 0.0982
# val Loss: 2.3097 Acc: 0.1000
#
# Epoch 9/19
# ----------
# train Loss: 2.3281 Acc: 0.0993
# val Loss: 2.3092 Acc: 0.1000
#
# Epoch 10/19
# ----------
# train Loss: 2.3281 Acc: 0.0996
# val Loss: 2.3087 Acc: 0.1000
#
# saved epoch 10 on ative_kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 2.3276 Acc: 0.1003
# val Loss: 2.3084 Acc: 0.1000
#
# Epoch 12/19
# ----------
# train Loss: 2.3272 Acc: 0.0977
# val Loss: 2.3080 Acc: 0.1000
#
# Epoch 13/19
# ----------
# train Loss: 2.3263 Acc: 0.1000
# val Loss: 2.3078 Acc: 0.1000
#
# Epoch 14/19
# ----------
# train Loss: 2.3252 Acc: 0.1013
# val Loss: 2.3075 Acc: 0.1000
#
# Epoch 15/19
# ----------
# train Loss: 2.3262 Acc: 0.1002
# val Loss: 2.3073 Acc: 0.1000
#
# saved epoch 15 on ative_kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 2.3247 Acc: 0.1015
# val Loss: 2.3072 Acc: 0.1000
#
# Epoch 17/19
# ----------
# train Loss: 2.3258 Acc: 0.1015
# val Loss: 2.3071 Acc: 0.1000
#
# Epoch 18/19
# ----------
# train Loss: 2.3251 Acc: 0.1009
# val Loss: 2.3070 Acc: 0.1000
#
# Epoch 19/19
# ----------
# train Loss: 2.3267 Acc: 0.1009
# val Loss: 2.3069 Acc: 0.1000
#
# Training complete in 20m 57s
# Best val Acc: 0.100000
#
#
#
#
# vgg19-init=distorted_kaiming_uniform-on-cifar_trn-20epochs-adam
# ===============================================================
# Epoch 0/19
# ----------
# train Loss: 0.2657 Acc: 0.9092
# val Loss: 1.0109 Acc: 0.7325
#
# saved epoch 0 on torted_kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.2283 Acc: 0.9221
# val Loss: 0.9766 Acc: 0.7424
#
# Epoch 2/19
# ----------
# train Loss: 0.1973 Acc: 0.9336
# val Loss: 1.0647 Acc: 0.7362
#
# Epoch 3/19
# ----------
# train Loss: 0.1700 Acc: 0.9425
# val Loss: 1.0314 Acc: 0.7403
#
# Epoch 4/19
# ----------
# train Loss: 0.1562 Acc: 0.9475
# val Loss: 1.0896 Acc: 0.7473
#
# Epoch 5/19
# ----------
# train Loss: 0.1273 Acc: 0.9581
# val Loss: 1.1561 Acc: 0.7441
#
# saved epoch 5 on torted_kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.1185 Acc: 0.9596
# val Loss: 1.1308 Acc: 0.7422
#
# Epoch 7/19
# ----------
# train Loss: 0.1045 Acc: 0.9652
# val Loss: 1.2104 Acc: 0.7353
#
# Epoch 8/19
# ----------
# train Loss: 0.0905 Acc: 0.9697
# val Loss: 1.1622 Acc: 0.7411
#
# Epoch 9/19
# ----------
# train Loss: 0.0842 Acc: 0.9721
# val Loss: 1.2906 Acc: 0.7292
#
# Epoch 10/19
# ----------
# train Loss: 0.0770 Acc: 0.9743
# val Loss: 1.2832 Acc: 0.7476
#
# saved epoch 10 on orted_kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.0824 Acc: 0.9722
# val Loss: 1.1252 Acc: 0.7444
#
# Epoch 12/19
# ----------
# train Loss: 0.0653 Acc: 0.9791
# val Loss: 1.2793 Acc: 0.7402
#
# Epoch 13/19
# ----------
# train Loss: 0.0636 Acc: 0.9787
# val Loss: 1.2158 Acc: 0.7487
#
# Epoch 14/19
# ----------
# train Loss: 0.0488 Acc: 0.9842
# val Loss: 1.2422 Acc: 0.7451
#
# Epoch 15/19
# ----------
# train Loss: 0.0534 Acc: 0.9827
# val Loss: 1.2650 Acc: 0.7519
#
# saved epoch 15 on orted_kaiming_uniform-on-cifar_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0525 Acc: 0.9819
# val Loss: 1.2333 Acc: 0.7466
#
# Epoch 17/19
# ----------
# train Loss: 0.0438 Acc: 0.9857
# val Loss: 1.2986 Acc: 0.7579
#
# Epoch 18/19
# ----------
# train Loss: 0.0404 Acc: 0.9872
# val Loss: 1.3048 Acc: 0.7546
#
# Epoch 19/19
# ----------
# train Loss: 0.0381 Acc: 0.9873
# val Loss: 1.3647 Acc: 0.7519
#
# Training complete in 21m 37s
# Best val Acc: 0.757900
#
#
#
#
# vgg19-init=kaiming_normal-on-mnist_trn-20epochs-adam
# ====================================================
# Epoch 0/19
# ----------
# train Loss: 1.5562 Acc: 0.5391
# val Loss: 0.1315 Acc: 0.9631
#
# saved epoch 0 on 19-init=kaiming_normal-on-mnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.1081 Acc: 0.9712
# val Loss: 0.0522 Acc: 0.9852
#
# Epoch 2/19
# ----------
# train Loss: 0.0598 Acc: 0.9839
# val Loss: 0.0429 Acc: 0.9874
#
# Epoch 3/19
# ----------
# train Loss: 0.0390 Acc: 0.9894
# val Loss: 0.0446 Acc: 0.9894
#
# Epoch 4/19
# ----------
# train Loss: 0.0295 Acc: 0.9914
# val Loss: 0.0355 Acc: 0.9910
#
# Epoch 5/19
# ----------
# train Loss: 0.0221 Acc: 0.9936
# val Loss: 0.0392 Acc: 0.9895
#
# saved epoch 5 on 19-init=kaiming_normal-on-mnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.0186 Acc: 0.9946
# val Loss: 0.0305 Acc: 0.9915
#
# Epoch 7/19
# ----------
# train Loss: 0.0135 Acc: 0.9964
# val Loss: 0.0397 Acc: 0.9901
#
# Epoch 8/19
# ----------
# train Loss: 0.0110 Acc: 0.9970
# val Loss: 0.0316 Acc: 0.9923
#
# Epoch 9/19
# ----------
# train Loss: 0.0098 Acc: 0.9972
# val Loss: 0.0323 Acc: 0.9925
#
# Epoch 10/19
# ----------
# train Loss: 0.0076 Acc: 0.9979
# val Loss: 0.0268 Acc: 0.9929
#
# saved epoch 10 on 9-init=kaiming_normal-on-mnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.0072 Acc: 0.9980
# val Loss: 0.0259 Acc: 0.9929
#
# Epoch 12/19
# ----------
# train Loss: 0.0046 Acc: 0.9986
# val Loss: 0.0320 Acc: 0.9925
#
# Epoch 13/19
# ----------
# train Loss: 0.0042 Acc: 0.9988
# val Loss: 0.0339 Acc: 0.9927
#
# Epoch 14/19
# ----------
# train Loss: 0.0047 Acc: 0.9987
# val Loss: 0.0352 Acc: 0.9923
#
# Epoch 15/19
# ----------
# train Loss: 0.0041 Acc: 0.9988
# val Loss: 0.0394 Acc: 0.9909
#
# saved epoch 15 on 9-init=kaiming_normal-on-mnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0038 Acc: 0.9989
# val Loss: 0.0414 Acc: 0.9917
#
# Epoch 17/19
# ----------
# train Loss: 0.0068 Acc: 0.9981
# val Loss: 0.0282 Acc: 0.9932
#
# Epoch 18/19
# ----------
# train Loss: 0.0035 Acc: 0.9990
# val Loss: 0.0307 Acc: 0.9942
#
# Epoch 19/19
# ----------
# train Loss: 0.0019 Acc: 0.9995
# val Loss: 0.0367 Acc: 0.9929
#
# Training complete in 25m 53s
# Best val Acc: 0.994200
#
#
#
#
# vgg19-init=negative_kaiming_normal-on-mnist_trn-20epochs-adam
# =============================================================
# Epoch 0/19
# ----------
# train Loss: 87879.4513 Acc: 0.0996
# val Loss: 2.3185 Acc: 0.1135
#
# saved epoch 0 on egative_kaiming_normal-on-mnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 2.3721 Acc: 0.1006
# val Loss: 2.3150 Acc: 0.1135
#
# Epoch 2/19
# ----------
# train Loss: 2.3589 Acc: 0.1012
# val Loss: 2.3096 Acc: 0.1135
#
# Epoch 3/19
# ----------
# train Loss: 2.3511 Acc: 0.1018
# val Loss: 2.3081 Acc: 0.1135
#
# Epoch 4/19
# ----------
# train Loss: 2.3266 Acc: 0.1125
# val Loss: 2.1449 Acc: 0.1570
#
# Epoch 5/19
# ----------
# train Loss: 1.9853 Acc: 0.2481
# val Loss: 1.7592 Acc: 0.3048
#
# saved epoch 5 on egative_kaiming_normal-on-mnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 1.6762 Acc: 0.3329
# val Loss: 1.4428 Acc: 0.3942
#
# Epoch 7/19
# ----------
# train Loss: 1.4917 Acc: 0.3824
# val Loss: 1.3072 Acc: 0.4295
#
# Epoch 8/19
# ----------
# train Loss: 1.3793 Acc: 0.4221
# val Loss: 1.3890 Acc: 0.4163
#
# Epoch 9/19
# ----------
# train Loss: 1.3187 Acc: 0.4504
# val Loss: 1.1609 Acc: 0.5243
#
# Epoch 10/19
# ----------
# train Loss: 1.2163 Acc: 0.4997
# val Loss: 1.0150 Acc: 0.5973
#
# saved epoch 10 on gative_kaiming_normal-on-mnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 1.1142 Acc: 0.5571
# val Loss: 0.9768 Acc: 0.5925
#
# Epoch 12/19
# ----------
# train Loss: 0.9100 Acc: 0.6595
# val Loss: 0.6827 Acc: 0.7651
#
# Epoch 13/19
# ----------
# train Loss: 0.7281 Acc: 0.7605
# val Loss: 0.5319 Acc: 0.8378
#
# Epoch 14/19
# ----------
# train Loss: 0.6231 Acc: 0.8064
# val Loss: 0.6094 Acc: 0.7994
#
# Epoch 15/19
# ----------
# train Loss: 0.5252 Acc: 0.8418
# val Loss: 0.3713 Acc: 0.8886
#
# saved epoch 15 on gative_kaiming_normal-on-mnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.4417 Acc: 0.8721
# val Loss: 0.3373 Acc: 0.8959
#
# Epoch 17/19
# ----------
# train Loss: 0.3728 Acc: 0.8943
# val Loss: 0.2698 Acc: 0.9210
#
# Epoch 18/19
# ----------
# train Loss: 0.3294 Acc: 0.9067
# val Loss: 0.2682 Acc: 0.9175
#
# Epoch 19/19
# ----------
# train Loss: 0.2842 Acc: 0.9202
# val Loss: 0.2005 Acc: 0.9403
#
# Training complete in 24m 57s
# Best val Acc: 0.940300
#
#
#
#
# vgg19-init=distorted_kaiming_normal-on-mnist_trn-20epochs-adam
# ==============================================================
# Epoch 0/19
# ----------
# train Loss: 0.0022 Acc: 0.9995
# val Loss: 0.0313 Acc: 0.9944
#
# saved epoch 0 on storted_kaiming_normal-on-mnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 0.0298 Acc: 0.9945
#
# Epoch 2/19
# ----------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.0348 Acc: 0.9939
#
# Epoch 3/19
# ----------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0377 Acc: 0.9937
#
# Epoch 4/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0364 Acc: 0.9942
#
# Epoch 5/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0386 Acc: 0.9944
#
# saved epoch 5 on storted_kaiming_normal-on-mnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.0396 Acc: 0.9941
#
# Epoch 7/19
# ----------
# train Loss: 0.0004 Acc: 0.9999
# val Loss: 0.0384 Acc: 0.9935
#
# Epoch 8/19
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0349 Acc: 0.9933
#
# Epoch 9/19
# ----------
# train Loss: 0.0038 Acc: 0.9989
# val Loss: 0.0432 Acc: 0.9919
#
# Epoch 10/19
# ----------
# train Loss: 0.0026 Acc: 0.9993
# val Loss: 0.0368 Acc: 0.9922
#
# saved epoch 10 on torted_kaiming_normal-on-mnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.0022 Acc: 0.9993
# val Loss: 0.0402 Acc: 0.9928
#
# Epoch 12/19
# ----------
# train Loss: 0.0023 Acc: 0.9992
# val Loss: 0.0409 Acc: 0.9923
#
# Epoch 13/19
# ----------
# train Loss: 0.0019 Acc: 0.9995
# val Loss: 0.0284 Acc: 0.9936
#
# Epoch 14/19
# ----------
# train Loss: 0.0018 Acc: 0.9994
# val Loss: 0.0485 Acc: 0.9901
#
# Epoch 15/19
# ----------
# train Loss: 0.0015 Acc: 0.9995
# val Loss: 0.0400 Acc: 0.9925
#
# saved epoch 15 on torted_kaiming_normal-on-mnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0004 Acc: 0.9999
# val Loss: 0.0388 Acc: 0.9930
#
# Epoch 17/19
# ----------
# train Loss: 0.0009 Acc: 0.9998
# val Loss: 0.0359 Acc: 0.9934
#
# Epoch 18/19
# ----------
# train Loss: 0.0005 Acc: 0.9998
# val Loss: 0.0388 Acc: 0.9928
#
# Epoch 19/19
# ----------
# train Loss: 0.0018 Acc: 0.9995
# val Loss: 0.0295 Acc: 0.9930
#
# Training complete in 25m 48s
# Best val Acc: 0.994500
#
#
#
#
# vgg19-init=kaiming_normal-on-fmnist_trn-20epochs-adam
# =====================================================
# Epoch 0/19
# ----------
# train Loss: 0.9169 Acc: 0.6656
# val Loss: 0.4320 Acc: 0.8452
#
# saved epoch 0 on 9-init=kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.3633 Acc: 0.8709
# val Loss: 0.3608 Acc: 0.8720
#
# Epoch 2/19
# ----------
# train Loss: 0.2958 Acc: 0.8937
# val Loss: 0.3290 Acc: 0.8821
#
# Epoch 3/19
# ----------
# train Loss: 0.2525 Acc: 0.9096
# val Loss: 0.3112 Acc: 0.8935
#
# Epoch 4/19
# ----------
# train Loss: 0.2249 Acc: 0.9194
# val Loss: 0.3004 Acc: 0.8985
#
# Epoch 5/19
# ----------
# train Loss: 0.1992 Acc: 0.9280
# val Loss: 0.2756 Acc: 0.9052
#
# saved epoch 5 on 9-init=kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.1814 Acc: 0.9340
# val Loss: 0.2710 Acc: 0.9088
#
# Epoch 7/19
# ----------
# train Loss: 0.1602 Acc: 0.9421
# val Loss: 0.2869 Acc: 0.9075
#
# Epoch 8/19
# ----------
# train Loss: 0.1462 Acc: 0.9472
# val Loss: 0.2491 Acc: 0.9177
#
# Epoch 9/19
# ----------
# train Loss: 0.1297 Acc: 0.9535
# val Loss: 0.2543 Acc: 0.9220
#
# Epoch 10/19
# ----------
# train Loss: 0.1175 Acc: 0.9574
# val Loss: 0.3008 Acc: 0.9110
#
# saved epoch 10 on -init=kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.1057 Acc: 0.9620
# val Loss: 0.2712 Acc: 0.9215
#
# Epoch 12/19
# ----------
# train Loss: 0.0956 Acc: 0.9653
# val Loss: 0.2913 Acc: 0.9122
#
# Epoch 13/19
# ----------
# train Loss: 0.0890 Acc: 0.9675
# val Loss: 0.2839 Acc: 0.9212
#
# Epoch 14/19
# ----------
# train Loss: 0.0793 Acc: 0.9717
# val Loss: 0.3424 Acc: 0.9130
#
# Epoch 15/19
# ----------
# train Loss: 0.0735 Acc: 0.9737
# val Loss: 0.3067 Acc: 0.9173
#
# saved epoch 15 on -init=kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0641 Acc: 0.9777
# val Loss: 0.3233 Acc: 0.9166
#
# Epoch 17/19
# ----------
# train Loss: 0.0590 Acc: 0.9790
# val Loss: 0.3166 Acc: 0.9223
#
# Epoch 18/19
# ----------
# train Loss: 0.0523 Acc: 0.9813
# val Loss: 0.3121 Acc: 0.9151
#
# Epoch 19/19
# ----------
# train Loss: 0.0468 Acc: 0.9834
# val Loss: 0.3191 Acc: 0.9210
#
# Training complete in 25m 52s
# Best val Acc: 0.922300
#
#
#
#
# vgg19-init=negative_kaiming_normal-on-fmnist_trn-20epochs-adam
# ==============================================================
# Epoch 0/19
# ----------
# train Loss: 341086.7781 Acc: 0.1602
# val Loss: 2.0242 Acc: 0.2758
#
# saved epoch 0 on gative_kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 1.8573 Acc: 0.2810
# val Loss: 1.6260 Acc: 0.3492
#
# Epoch 2/19
# ----------
# train Loss: 1.6864 Acc: 0.3340
# val Loss: 1.5385 Acc: 0.4182
#
# Epoch 3/19
# ----------
# train Loss: 1.5970 Acc: 0.3809
# val Loss: 1.4944 Acc: 0.4336
#
# Epoch 4/19
# ----------
# train Loss: 1.4482 Acc: 0.4293
# val Loss: 1.2940 Acc: 0.5112
#
# Epoch 5/19
# ----------
# train Loss: 1.3408 Acc: 0.4748
# val Loss: 1.2943 Acc: 0.4991
#
# saved epoch 5 on gative_kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 1.2460 Acc: 0.5133
# val Loss: 1.2345 Acc: 0.5116
#
# Epoch 7/19
# ----------
# train Loss: 1.1812 Acc: 0.5367
# val Loss: 1.1085 Acc: 0.5690
#
# Epoch 8/19
# ----------
# train Loss: 1.1254 Acc: 0.5576
# val Loss: 1.0266 Acc: 0.6022
#
# Epoch 9/19
# ----------
# train Loss: 1.0794 Acc: 0.5773
# val Loss: 1.0243 Acc: 0.5997
#
# Epoch 10/19
# ----------
# train Loss: 1.0174 Acc: 0.6020
# val Loss: 1.2352 Acc: 0.5162
#
# saved epoch 10 on ative_kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.9750 Acc: 0.6179
# val Loss: 0.9265 Acc: 0.6299
#
# Epoch 12/19
# ----------
# train Loss: 0.9319 Acc: 0.6364
# val Loss: 0.8640 Acc: 0.6548
#
# Epoch 13/19
# ----------
# train Loss: 0.8816 Acc: 0.6582
# val Loss: 0.8171 Acc: 0.6865
#
# Epoch 14/19
# ----------
# train Loss: 0.8452 Acc: 0.6744
# val Loss: 0.8367 Acc: 0.6775
#
# Epoch 15/19
# ----------
# train Loss: 0.8166 Acc: 0.6865
# val Loss: 0.8586 Acc: 0.6655
#
# saved epoch 15 on ative_kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.7933 Acc: 0.6954
# val Loss: 0.7401 Acc: 0.7107
#
# Epoch 17/19
# ----------
# train Loss: 0.7698 Acc: 0.7043
# val Loss: 0.7228 Acc: 0.7191
#
# Epoch 18/19
# ----------
# train Loss: 0.7458 Acc: 0.7108
# val Loss: 0.7125 Acc: 0.7258
#
# Epoch 19/19
# ----------
# train Loss: 0.7098 Acc: 0.7268
# val Loss: 0.7155 Acc: 0.7302
#
# Training complete in 25m 1s
# Best val Acc: 0.730200
#
#
#
#
# vgg19-init=distorted_kaiming_normal-on-fmnist_trn-20epochs-adam
# ===============================================================
# Epoch 0/19
# ----------
# train Loss: 0.0529 Acc: 0.9815
# val Loss: 0.2953 Acc: 0.9244
#
# saved epoch 0 on torted_kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 0.0474 Acc: 0.9831
# val Loss: 0.3191 Acc: 0.9229
#
# Epoch 2/19
# ----------
# train Loss: 0.0439 Acc: 0.9846
# val Loss: 0.3503 Acc: 0.9202
#
# Epoch 3/19
# ----------
# train Loss: 0.0391 Acc: 0.9856
# val Loss: 0.3404 Acc: 0.9203
#
# Epoch 4/19
# ----------
# train Loss: 0.0377 Acc: 0.9871
# val Loss: 0.3490 Acc: 0.9185
#
# Epoch 5/19
# ----------
# train Loss: 0.0330 Acc: 0.9884
# val Loss: 0.3478 Acc: 0.9192
#
# saved epoch 5 on torted_kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.0299 Acc: 0.9895
# val Loss: 0.3924 Acc: 0.9213
#
# Epoch 7/19
# ----------
# train Loss: 0.0254 Acc: 0.9913
# val Loss: 0.3841 Acc: 0.9184
#
# Epoch 8/19
# ----------
# train Loss: 0.0254 Acc: 0.9911
# val Loss: 0.4216 Acc: 0.9157
#
# Epoch 9/19
# ----------
# train Loss: 0.0263 Acc: 0.9904
# val Loss: 0.3995 Acc: 0.9212
#
# Epoch 10/19
# ----------
# train Loss: 0.0227 Acc: 0.9921
# val Loss: 0.4085 Acc: 0.9178
#
# saved epoch 10 on orted_kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------
# train Loss: 0.0250 Acc: 0.9913
# val Loss: 0.4018 Acc: 0.9210
#
# Epoch 12/19
# ----------
# train Loss: 0.0197 Acc: 0.9930
# val Loss: 0.4199 Acc: 0.9239
#
# Epoch 13/19
# ----------
# train Loss: 0.0139 Acc: 0.9951
# val Loss: 0.4458 Acc: 0.9187
#
# Epoch 14/19
# ----------
# train Loss: 0.0158 Acc: 0.9946
# val Loss: 0.4533 Acc: 0.9199
#
# Epoch 15/19
# ----------
# train Loss: 0.0132 Acc: 0.9956
# val Loss: 0.4218 Acc: 0.9191
#
# saved epoch 15 on orted_kaiming_normal-on-fmnist_trn-20epochs-adam/epoch_15.pt
# Epoch 16/19
# ----------
# train Loss: 0.0161 Acc: 0.9947
# val Loss: 0.4846 Acc: 0.9197
#
# Epoch 17/19
# ----------
# train Loss: 0.0126 Acc: 0.9957
# val Loss: 0.4286 Acc: 0.9230
#
# Epoch 18/19
# ----------
# train Loss: 0.0143 Acc: 0.9951
# val Loss: 0.4387 Acc: 0.9203
#
# Epoch 19/19
# ----------
# train Loss: 0.0173 Acc: 0.9943
# val Loss: 0.4370 Acc: 0.9247
#
# Training complete in 25m 52s
# Best val Acc: 0.924700
#
#
#
#
# vgg19-init=kaiming_normal-on-cifar_trn-20epochs-adam
# ====================================================
# Epoch 0/19
# ----------
# train Loss: 2.3109 Acc: 0.1335
# val Loss: 1.9144 Acc: 0.2204
#
# saved epoch 0 on 19-init=kaiming_normal-on-cifar_trn-20epochs-adam/epoch_0.pt
# Epoch 1/19
# ----------
# train Loss: 1.8055 Acc: 0.2680
# val Loss: 1.5305 Acc: 0.4062
#
# Epoch 2/19
# ----------
# train Loss: 1.3976 Acc: 0.4751
# val Loss: 1.1915 Acc: 0.5729
#
# Epoch 3/19
# ----------
# train Loss: 1.1068 Acc: 0.6030
# val Loss: 1.1132 Acc: 0.6264
#
# Epoch 4/19
# ----------
# train Loss: 0.9323 Acc: 0.6679
# val Loss: 0.9387 Acc: 0.6693
#
# Epoch 5/19
# ----------
# train Loss: 0.8075 Acc: 0.7187
# val Loss: 0.8544 Acc: 0.7023
#
# saved epoch 5 on 19-init=kaiming_normal-on-cifar_trn-20epochs-adam/epoch_5.pt
# Epoch 6/19
# ----------
# train Loss: 0.7037 Acc: 0.7560
# val Loss: 0.8808 Acc: 0.7049
#
# Epoch 7/19
# ----------
# train Loss: 0.6081 Acc: 0.7900
# val Loss: 0.8318 Acc: 0.7234
#
# Epoch 8/19
# ----------
# train Loss: 0.5174 Acc: 0.8221
# val Loss: 0.8365 Acc: 0.7248
#
# Epoch 9/19
# ----------
# train Loss: 0.4569 Acc: 0.8433
# val Loss: 0.8129 Acc: 0.7418
#
# Epoch 10/19
# ----------
# train Loss: 0.3872 Acc: 0.8692
# val Loss: 0.8370 Acc: 0.7466
#
# saved epoch 10 on 9-init=kaiming_normal-on-cifar_trn-20epochs-adam/epoch_10.pt
# Epoch 11/19
# ----------

# %%
# !rm -rf /content/drive/MyDrive/Saravanan/training_data_adam/vgg19-init=kaiming_uniform-on-mnist_trn-20epochs-adam
# !mkdir /content/drive/MyDrive/Saravanan/training_data_vggnet

# %%
# !zip saravanan.zip -r /content/drive/MyDrive/Saravanan/
# Out:
#   adding: content/drive/MyDrive/Saravanan/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/t10k-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/t10k-labels-idx1-ubyte (deflated 55%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/train-labels-idx1-ubyte (deflated 52%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/t10k-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/train-images-idx3-ubyte (deflated 79%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/train-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/train-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/raw/t10k-images-idx3-ubyte (deflated 79%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/processed/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/processed/training.pt (deflated 79%)
#   adding: content/drive/MyDrive/Saravanan/MNIST/processed/test.pt (deflated 79%)
#   adding: content/drive/MyDrive/Saravanan/MNIST.tar.gz.1 (deflated 0%)
#   adding: content/drive/MyDrive/Saravanan/.ipynb_checkpoints/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/__pycache__/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/__pycache__/train_helper.cpython-37.pyc (deflated 36%)
#   adding: content/drive/MyDrive/Saravanan/__pycache__/initializations.cpython-37.pyc (deflated 39%)
#   adding: content/drive/MyDrive/Saravanan/__pycache__/lenet.cpython-37.pyc (deflated 38%)
#   adding: content/drive/MyDrive/Saravanan/__pycache__/datasets.cpython-37.pyc (deflated 47%)
#   adding: content/drive/MyDrive/Saravanan/data/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/test_batch (deflated 8%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/data_batch_3 (deflated 8%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/data_batch_2 (deflated 8%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/data_batch_5 (deflated 8%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/data_batch_1 (deflated 9%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/data_batch_4 (deflated 8%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/batches.meta (deflated 12%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-batches-py/readme.html (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/train-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/train-images-idx3-ubyte (deflated 44%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/train-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/train-labels-idx1-ubyte (deflated 51%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/t10k-images-idx3-ubyte (deflated 44%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/raw/t10k-labels-idx1-ubyte (deflated 49%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/processed/ (stored 0%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/processed/training.pt (deflated 44%)
#   adding: content/drive/MyDrive/Saravanan/data/FashionMNIST/processed/test.pt (deflated 44%)
#   adding: content/drive/MyDrive/Saravanan/data/cifar-10-python.tar.gz
#
#
# zip error: Interrupted (aborting)

# %%
# rm -rf "/content/drive/MyDrive/Saravanan/training_data (1)"
